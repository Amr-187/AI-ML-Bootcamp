# %% [markdown]
# <a href="https://colab.research.google.com/github/Amr-187/AI-ML-Bootcamp/blob/main/Car_Dataset_Analysis_Amrina_Rahman.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
path='/content/drive/MyDrive/AI & ML Bootcamp 2024/Class 1_ Linear Regression/CAR DETAILS FROM CAR DEKHO.csv'
df=pd.read_csv(path)
df
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#         fuel seller_type transmission         owner
# ...

# %% [markdown]
# ## Overview of the Car Dataset

# %%
df.describe()
# Out:
#               year  selling_price      km_driven
# count  4340.000000   4.340000e+03    4340.000000
# mean   2013.090783   5.041273e+05   66215.777419
# std       4.215344   5.785487e+05   46644.102194
# min    1992.000000   2.000000e+04       1.000000
# 25%    2011.000000   2.087498e+05   35000.000000
# 50%    2014.000000   3.500000e+05   60000.000000
# 75%    2016.000000   6.000000e+05   90000.000000
# max    2020.000000   8.900000e+06  806599.000000

# %%
df.count()
# Out:
# name             4340
# year             4340
# selling_price    4340
# km_driven        4340
# fuel             4340
# seller_type      4340
# transmission     4340
# owner            4340
# dtype: int64

# %%
df.dtypes
# Out:
# name             object
# year              int64
# selling_price     int64
# km_driven         int64
# fuel             object
# seller_type      object
# transmission     object
# owner            object
# dtype: object

# %%
df.name.value_counts()
# Out:
# name
# Maruti Swift Dzire VDI                     69
# Maruti Alto 800 LXI                        59
# Maruti Alto LXi                            47
# Maruti Alto LX                             35
# Hyundai EON Era Plus                       35
#                                            ..
# Hyundai Verna Transform CRDi VGT SX ABS     1
# Maruti S-Presso VXI Plus                    1
# Toyota Etios Liva 1.2 VX                    1
# Toyota Yaris G                              1
# Hyundai i20 Magna 1.4 CRDi                  1
# Name: count, Length: 1491, dtype: int64

# %%
df.year.value_counts()
# Out:
# year
# 2017    466
# 2015    421
# 2012    415
# 2013    386
# 2014    367
# 2018    366
# 2016    357
# 2011    271
# 2010    234
# 2019    195
# 2009    193
# 2008    145
# 2007    134
# 2006    110
# 2005     85
# 2020     48
# 2004     42
# 2003     23
# 2002     21
# 2001     20
# 1998     12
# 2000     12
# 1999     10
# 1997      3
# 1996      2
# 1995      1
# 1992      1
# Name: count, dtype: int64

# %%
df.seller_type.value_counts()
# Out:
# seller_type
# Individual          3244
# Dealer               994
# Trustmark Dealer     102
# Name: count, dtype: int64

# %%
df.fuel.value_counts()
# Out:
# fuel
# Diesel      2153
# Petrol      2123
# CNG           40
# LPG           23
# Electric       1
# Name: count, dtype: int64

# %%
df.transmission.value_counts()
# Out:
# transmission
# Manual       3892
# Automatic     448
# Name: count, dtype: int64

# %%
df.owner.value_counts()
# Out:
# owner
# First Owner             2832
# Second Owner            1106
# Third Owner              304
# Fourth & Above Owner      81
# Test Drive Car            17
# Name: count, dtype: int64

# %% [markdown]
# ## Simple Linear Regression

# %% [markdown]
# **Price vs. km_driven**

# %%
X=df['km_driven']
y=df['selling_price']

# %%
X=sm.add_constant(X)

# %%
model0 = sm.OLS(y,X).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:          selling_price   R-squared:                       0.037
# Model:                            OLS   Adj. R-squared:                  0.037
# Method:                 Least Squares   F-statistic:                     166.6
# Date:                Fri, 13 Sep 2024   Prob (F-statistic):           2.03e-37
# Time:                        11:18:17   Log-Likelihood:                -63660.
# No. Observations:                4340   AIC:                         1.273e+05
# Df Residuals:                    4338   BIC:                         1.273e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       6.621e+05    1.5e+04     44.232      0.000    6.33e+05    6.91e+05
# ...

# %% [markdown]
# **Price vs. Year**

# %%
X1=df['year']
y1=df['selling_price']

# %%
X1=sm.add_constant(X1)

# %%
model1=sm.OLS(y1,X1).fit()

# %%
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:          selling_price   R-squared:                       0.171
# Model:                            OLS   Adj. R-squared:                  0.171
# Method:                 Least Squares   F-statistic:                     896.9
# Date:                Fri, 13 Sep 2024   Prob (F-statistic):          2.72e-179
# Time:                        11:27:08   Log-Likelihood:                -63334.
# No. Observations:                4340   AIC:                         1.267e+05
# Df Residuals:                    4338   BIC:                         1.267e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1.139e+08   3.82e+06    -29.816      0.000   -1.21e+08   -1.06e+08
# ...

# %% [markdown]
# **Multiple Linear Regression**

# %% [markdown]
# **Price vs. km, Year**

# %%
X2=df[['year','km_driven']]
y2=df['selling_price']

# %%
X2=sm.add_constant(X2)

# %%
model2=sm.OLS(y2,X2).fit()

# %%
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:          selling_price   R-squared:                       0.172
# Model:                            OLS   Adj. R-squared:                  0.171
# Method:                 Least Squares   F-statistic:                     449.7
# Date:                Fri, 13 Sep 2024   Prob (F-statistic):          3.41e-178
# Time:                        11:43:13   Log-Likelihood:                -63333.
# No. Observations:                4340   AIC:                         1.267e+05
# Df Residuals:                    4337   BIC:                         1.267e+05
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1.112e+08   4.21e+06    -26.408      0.000   -1.19e+08   -1.03e+08
# ...

# %% [markdown]
# **One Hot Encoding**

# %%
df = pd.get_dummies(df, columns=['transmission','fuel','owner','seller_type'], drop_first=False)

# %%
df
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#       transmission_Automatic  transmission_Manual  fuel_CNG  fuel_Diesel  \
# ...

# %%
print(df.dtypes)
# Out:
# name                            object
# year                             int64
# selling_price                    int64
# km_driven                        int64
# transmission_Automatic            bool
# transmission_Manual               bool
# fuel_CNG                          bool
# fuel_Diesel                       bool
# fuel_Electric                     bool
# fuel_LPG                          bool
# fuel_Petrol                       bool
# owner_First Owner                 bool
# owner_Fourth & Above Owner        bool
# owner_Second Owner                bool
# owner_Test Drive Car              bool
# owner_Third Owner                 bool
# seller_type_Dealer                bool
# seller_type_Individual            bool
# seller_type_Trustmark Dealer      bool
# dtype: object

# %%
for col in df.columns:
  if df[col].dtype=='bool':
    df[col]=df[col].astype(int)

df
# Out:
#                                      name  year  selling_price  km_driven  \
# 0                           Maruti 800 AC  2007          60000      70000
# 1                Maruti Wagon R LXI Minor  2007         135000      50000
# 2                    Hyundai Verna 1.6 SX  2012         600000     100000
# 3                  Datsun RediGO T Option  2017         250000      46000
# 4                   Honda Amaze VX i-DTEC  2014         450000     141000
# ...                                   ...   ...            ...        ...
# 4335  Hyundai i20 Magna 1.4 CRDi (Diesel)  2014         409999      80000
# 4336           Hyundai i20 Magna 1.4 CRDi  2014         409999      80000
# 4337                  Maruti 800 AC BSIII  2009         110000      83000
# 4338     Hyundai Creta 1.6 CRDi SX Option  2016         865000      90000
# 4339                     Renault KWID RXT  2016         225000      40000
#
#       transmission_Automatic  transmission_Manual  fuel_CNG  fuel_Diesel  \
# ...

# %%
X4=df.drop(['name','selling_price'],axis=1)
y4=df['selling_price']

# %%
X4=sm.add_constant(X4)

# %%
model4=sm.OLS(y4,X4).fit()

# %%
model4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:          selling_price   R-squared:                       0.459
# Model:                            OLS   Adj. R-squared:                  0.458
# Method:                 Least Squares   F-statistic:                     282.6
# Date:                Fri, 13 Sep 2024   Prob (F-statistic):               0.00
# Time:                        13:03:34   Log-Likelihood:                -62408.
# No. Observations:                4340   AIC:                         1.248e+05
# Df Residuals:                    4326   BIC:                         1.249e+05
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# ...

# %%
X5=df.drop(['name','selling_price','owner_Fourth & Above Owner','owner_Test Drive Car','seller_type_Trustmark Dealer'],axis=1)
y5=df['selling_price']

# %%
X5=sm.add_constant(X5)

# %%
model5=sm.OLS(y4,X4).fit()

# %%
model5.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:          selling_price   R-squared:                       0.452
# Model:                            OLS   Adj. R-squared:                  0.451
# Method:                 Least Squares   F-statistic:                     510.5
# Date:                Fri, 13 Sep 2024   Prob (F-statistic):               0.00
# Time:                        13:17:28   Log-Likelihood:                -62437.
# No. Observations:                4340   AIC:                         1.249e+05
# Df Residuals:                    4332   BIC:                         1.249e+05
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# **Train Test Split**

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
X6=df.drop(['name','selling_price'],axis=1)
y6=df['selling_price']

# %%
X6_train, X6_test, y6_train, y6_test = train_test_split(X6,y6,test_size=0.2,random_state=42)

# %%
model6=LinearRegression()
model6.fit(X6_train,y6_train)
# Out:
# LinearRegression()

# %%
y6_pred=model6.predict(X6_test)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
plt.scatter(y6_test,y6_pred,color='green',label='Predicted vs. Actual')
plt.plot([min(y6_test),max(y6_test),min(y6_test),max(y6_test)],color='blue',linestyle='-',label='Completely Accurate Prediction')
plt.xlabel('Real Price')
plt.ylabel('Predicted Price')
plt.title('Real vs. Predicted Price')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

mse=mean_squared_error (y6_test,y6_pred)
rmse = np.sqrt(mse)
mae= mean_absolute_error(y6_test,y6_pred)
r2=r2_score(y6_test,y6_pred)

# %% [markdown]
# Performance Metrics

# %%
print(f"Mean Squared Error (MSE):{mse}")
print(f"Root Mean Squared Error (RMSE):{rmse}")
print(f"Mean Absolute Error (MAE):{mae}")
print(f"R-squared (R²):{r2}")
# Out:
# Mean Squared Error (MSE):182146878750.2804
# Root Mean Squared Error (RMSE):426786.68998725864
# Mean Absolute Error (MAE):221706.36930930047
# R-squared (R²):0.4031303601432136
